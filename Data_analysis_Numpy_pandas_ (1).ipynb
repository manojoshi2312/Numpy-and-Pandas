# %%
#Numpy

# %%
import numpy as np

# %%
temperatures_w1 =np.array([22.5, 25.3, 20.8, 23.4, 26.1, 24.8, 21.9]) #1D numpy array

# %%
print(temperatures_w1)
# Out:
# [22.5 25.3 20.8 23.4 26.1 24.8 21.9]

# %%
#inspection & properties

# %%
print(temperatures_w1.shape) #Shape
# Out:
# (7,)

# %%
print(temperatures_w1.dtype) #datatype
# Out:
# float64

# %%
print(temperatures_w1.size) #Number of elements
# Out:
# 7

# %%
#Array operations

# %%
T_Fahrenheit =(temperatures_w1*9/5)+32 #Convert celcuis to Fahrenheit

# %%
print(T_Fahrenheit)
# Out:
# [72.5  77.54 69.44 74.12 78.98 76.64 71.42]

# %%
print(np.max(temperatures_w1)) #Maximum
# Out:
# 26.1

# %%
print(np.min(temperatures_w1)) #Minimum
# Out:
# 20.8

# %%
print(np.mean(temperatures_w1)) #Mean
# Out:
# 23.542857142857144

# %%
#Array Slicing and Indexing

# %%
print(temperatures_w1[:3]) #First 3 days of the week
# Out:
# [22.5 25.3 20.8]

# %%
print(temperatures_w1[-2:]) #Last 2days
# Out:
# [24.8 21.9]

# %%
print(temperatures_w1[2:5]) #Middle 3days
# Out:
# [20.8 23.4 26.1]

# %%
#2D Array

# %%
temperatures =np.array([[22.5, 25.3, 20.8, 23.4, 26.1, 24.8, 21.9],[19.2, 22.5, 21.3, 24.0, 23.5, 22.8, 20.1]])

# %%
#Inspect and Slice the 2D Array

# %%
print(temperatures)
# Out:
# [[22.5 25.3 20.8 23.4 26.1 24.8 21.9]
#  [19.2 22.5 21.3 24.  23.5 22.8 20.1]]

# %%
print(temperatures.shape)
# Out:
# (2, 7)

# %%
print(temperatures.dtype)
# Out:
# float64

# %%
print(temperatures.size)
# Out:
# 14

# %%
#Extract

# %%
print(temperatures[0]) #1week
# Out:
# [22.5 25.3 20.8 23.4 26.1 24.8 21.9]

# %%
print(temperatures[1]) #2week
# Out:
# [19.2 22.5 21.3 24.  23.5 22.8 20.1]

# %%
print(temperatures[:,-2:]) #last 2 dys
# Out:
# [[24.8 21.9]
#  [22.8 20.1]]

# %%
#Pandas Series

# %%
import pandas as pd

# %%
marks =pd.Series([95, 92, 89, 85, 80],
                 index=['Rank1', 'Rank2', 'Rank3', 'Rank4', 'Rank5'])

# %%
print(marks)
# Out:
# Rank1    95
# Rank2    92
# Rank3    89
# Rank4    85
# Rank5    80
# dtype: int64

# %%
#Indexing and Slicing

# %%
print(marks[0])
# Out:
# 95
# /tmp/ipython-input-3296141910.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(marks[0])

# %%
print(marks.loc[['Rank1','Rank2','Rank3']])
# Out:
# Rank1    95
# Rank2    92
# Rank3    89
# dtype: int64

# %%
print(marks.iloc[2])
# Out:
# 89

# %%
print(marks[marks>90])
# Out:
# Rank1    95
# Rank2    92
# dtype: int64

# %%
#Manipulating Series

# %%
marks['Rank1']=100

# %%
marks=marks.drop('Rank5')

# %%
Cgpa=marks/10

# %%
print(marks)
# Out:
# Rank1    100
# Rank2     92
# Rank3     89
# Rank4     85
# dtype: int64

# %%
print(Cgpa)
# Out:
# Rank1    10.0
# Rank2     9.2
# Rank3     8.9
# Rank4     8.5
# dtype: float64

# %%
#Pandas Data frame

# %%
transactions=pd.DataFrame({
    'TransactionID':[101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
'ProductCategory':['Electronics', 'Clothing', 'Electronics', 'Furniture',
'Clothing', 'Electronics', 'Furniture', 'Clothing', 'Furniture', 'Electronics'],
'Region': ['North', 'South', 'North', 'East', 'West', 'North', 'East', 'West',
'South', 'North'],
 'Amount':[200, 150, 300, 450, 200, 250, 300, 180, 350, 400]})

# %%
#Data Exploration

# %%
print(transactions)
# Out:
#    TransactionID ProductCategory Region  Amount
# 0            101     Electronics  North     200
# 1            102        Clothing  South     150
# 2            103     Electronics  North     300
# 3            104       Furniture   East     450
# 4            105        Clothing   West     200
# 5            106     Electronics  North     250
# 6            107       Furniture   East     300
# 7            108        Clothing   West     180
# 8            109       Furniture  South     350
# 9            110     Electronics  North     400

# %%
print(transactions.head())
# Out:
#    TransactionID ProductCategory Region  Amount
# 0            101     Electronics  North     200
# 1            102        Clothing  South     150
# 2            103     Electronics  North     300
# 3            104       Furniture   East     450
# 4            105        Clothing   West     200

# %%
print(transactions.tail())
# Out:
#    TransactionID ProductCategory Region  Amount
# 5            106     Electronics  North     250
# 6            107       Furniture   East     300
# 7            108        Clothing   West     180
# 8            109       Furniture  South     350
# 9            110     Electronics  North     400

# %%
print(transactions.shape)
# Out:
# (10, 4)

# %%
print(transactions.columns)
# Out:
# Index(['TransactionID', 'ProductCategory', 'Region', 'Amount'], dtype='object')

# %%
print(transactions.dtypes)
# Out:
# TransactionID       int64
# ProductCategory    object
# Region             object
# Amount              int64
# dtype: object

# %%
print(transactions[['ProductCategory','Amount']])
# Out:
#   ProductCategory  Amount
# 0     Electronics     200
# 1        Clothing     150
# 2     Electronics     300
# 3       Furniture     450
# 4        Clothing     200
# 5     Electronics     250
# 6       Furniture     300
# 7        Clothing     180
# 8       Furniture     350
# 9     Electronics     400

# %%
print(transactions.iloc[:,-3:])
# Out:
#   ProductCategory Region  Amount
# 0     Electronics  North     200
# 1        Clothing  South     150
# 2     Electronics  North     300
# 3       Furniture   East     450
# 4        Clothing   West     200
# 5     Electronics  North     250
# 6       Furniture   East     300
# 7        Clothing   West     180
# 8       Furniture  South     350
# 9     Electronics  North     400

# %%
print(transactions[(transactions['Region']=='North')&(transactions['Amount']>200)])
# Out:
#    TransactionID ProductCategory Region  Amount
# 2            103     Electronics  North     300
# 5            106     Electronics  North     250
# 9            110     Electronics  North     400

# %%
print(transactions['ProductCategory'].value_counts())
# Out:
# ProductCategory
# Electronics    4
# Clothing       3
# Furniture      3
# Name: count, dtype: int64

# %%
print(transactions['Region'].unique())
# Out:
# ['North' 'South' 'East' 'West']

# %%
print(transactions.groupby('Region')['Amount'].mean())
# Out:
# Region
# East     375.0
# North    287.5
# South    250.0
# West     190.0
# Name: Amount, dtype: float64

# %%
#Manipulating the DataFrame

# %%
transactions.loc[transactions['TransactionID']== 102 ,'Amount']=165

# %%
print(transactions[1:-8])
# Out:
#    TransactionID ProductCategory Region  Amount
# 1            102        Clothing  South     165

# %%
transactions['Discount']=transactions['Amount']*0.10

# %%
print(transactions)
# Out:
#    TransactionID ProductCategory Region  Amount  Discount
# 0            101     Electronics  North     200      20.0
# 1            102        Clothing  South     165      16.5
# 2            103     Electronics  North     300      30.0
# 3            104       Furniture   East     450      45.0
# 4            105        Clothing   West     200      20.0
# 5            106     Electronics  North     250      25.0
# 6            107       Furniture   East     300      30.0
# 7            108        Clothing   West     180      18.0
# 8            109       Furniture  South     350      35.0
# 9            110     Electronics  North     400      40.0

# %%
transactions=transactions.drop(transactions[transactions['TransactionID']==109].index)

# %%
print(transactions)
# Out:
#    TransactionID ProductCategory Region  Amount  Discount
# 0            101     Electronics  North     200      20.0
# 1            102        Clothing  South     165      16.5
# 2            103     Electronics  North     300      30.0
# 3            104       Furniture   East     450      45.0
# 4            105        Clothing   West     200      20.0
# 5            106     Electronics  North     250      25.0
# 6            107       Furniture   East     300      30.0
# 7            108        Clothing   West     180      18.0
# 9            110     Electronics  North     400      40.0

# %%
transactions=transactions.drop('Discount',axis=1)

# %%
print(transactions)
# Out:
#    TransactionID ProductCategory Region  Amount
# 0            101     Electronics  North     200
# 1            102        Clothing  South     165
# 2            103     Electronics  North     300
# 3            104       Furniture   East     450
# 4            105        Clothing   West     200
# 5            106     Electronics  North     250
# 6            107       Furniture   East     300
# 7            108        Clothing   West     180
# 9            110     Electronics  North     400
